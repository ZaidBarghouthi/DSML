# %%
import pandas as pd

df = pd.read_csv("Data/data01.csv", sep=";", index_col=0)

df_m = df[df["Gender"] == "Male"]
df_f = df[df["Gender"] == "Female"]


for iq in ["FSIQ", "VIQ", "PIQ"]:
    print(f"{iq} mean> Males {df_m[iq].mean()} Females: {df_f[iq].mean()}")
# Out:
# FSIQ mean> Males 115.0 Females: 111.9
# VIQ mean> Males 115.25 Females: 109.45
# PIQ mean> Males 111.6 Females: 110.45

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as sta

s = np.round(np.random.normal(5,2,100000))

print(s[:3])
print(f"Mean: {s.mean()}, Median: {np.median(s)}, Mode: {sta.mode(s)}")
plt.hist(s)
plt.show()
# Out:
# [5. 7. 7.]
# Mean: 5.00679, Median: 5.0, Mode: 5.0
